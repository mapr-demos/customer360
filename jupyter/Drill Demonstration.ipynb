# %% [markdown]
# # Apache Drill in Action
#
# Apache Drill is a Unix service that unifies access to data across a variety of data formats and sources. It can run on a single node or on multiple nodes in a clustered environment. It supports a variety of NoSQL databases and file systems, including HBase, MongoDB, HDFS, Amazon S3, Azure Blob Storage, and local text files like json or csv files. Drill provides the following user friendly features:
# - Drill supports industry standard APIs such as ANSI SQL and JDBC
# - Drill enables you to perform queries without predefining schemas
# - Drill enables you to JOIN data in different formats from multiple datastores.
#
# This Jupyter notebook shows how to join relational and nonrelational datasets with Apache Drill.
#
# For more information about programming with Drill, see [the Apache Drill docs](https://drill.apache.org/docs/installing-the-driver-on-linux/).

# %%
# Import modules
import pyodbc
from pandas import *
import pandas as pd
import unicodedata
# Show datasources defined in ~/.odbc.ini
print(pyodbc.dataSources());
# Out:
# {'ODBC': '', 'drill64': '/opt/mapr/drillodbc/lib/64/libdrillodbc_sb64.so'}

# %%
# Initialize the connection
conn = pyodbc.connect("DSN=drill64;CHARSET=UTF8", autocommit=True)
conn.setdecoding(pyodbc.SQL_WMETADATA, encoding='utf-32le')
cursor = conn.cursor()

# %% [markdown]
# ## SELECT from a MapR-DB table:

# %%
data = pandas.read_sql("SELECT _id, name, address, phone_number, latitude, longitude, zip, first_visit, churn_risk, sentiment FROM `dfs.default`.`./tmp/crm_data` limit 100", conn)
data.address[0:10]
# Out:
# 0         48578 Sandy Maple Edge
# 1               64 Pretty Rock Dell
# 2    32279 Grand Castle Stre...
# 3     7103 Heather Axe Estates
# 4    15388 Sunny Beaver Aven...
# 5    43238 High Stone Promen...
# 6    1545 Merry Bridge Orcha...
# 7    13984 Thunder Turtle Su...
# 8    3590 Turning Butternut ...
# 9       3672 Rose Autumn Valley
# Name: address, dtype: object

# %% [markdown]
# ## SELECT from a CSV file:

# %%
# setup the query and run it
s = "SELECT * FROM `dfs.tmp`.`./companylist.csv2` limit 3"
data = pandas.read_sql(s, conn)
data
# Out:
#      Symbol                                               Name    LastSale  \
# 0    PIH  1347 Property Insurance...      7.2
# 1  FLWS     1-800 FLOWERS.COM, Inc.    10.2
# 2  FCCY  1st Constitution Bancor...  18.95
#
#                   MarketCap ADR TSO   IPOyear  \
# 0      42903835.2  n/a  2014
# 1    668804391.6  n/a  1999
# 2  151482301.55  n/a    n/a
#
#                                Sector  \
# 0                      Finance
# 1  Consumer Services
# 2                      Finance
#
#                                             Industry  \
# 0  Property-Casualty Insur...
# 1       Other Specialty Stores
# 2           Savings Institutions
#
#                                        Summary Quote  \
# 0  http://www.nasdaq.com/s...
# 1  http://www.nasdaq.com/s...
# 2  http://www.nasdaq.com/s...
#
#                                           fqn  \
# 0  /tmp/companylist.csv2
# 1  /tmp/companylist.csv2
# 2  /tmp/companylist.csv2
#
#                            filename  filepath    suffix
# 0  companylist.csv2  /tmp  csv2
# 1  companylist.csv2  /tmp  csv2
# 2  companylist.csv2  /tmp  csv2

# %%
# Fetch and display filtered output
cursor.execute(s)
row = cursor.fetchone() 
print row[0], row[1]
# Out:
# PIH 1347 Property Insurance Holdings, Inc.

# %% [markdown]
# ## SELECT from a relational database (MySQL):

# %%
# Here's how to select from MySQL
s = "select * from ianmysql.cars.`car`"
data = pandas.read_sql(s, conn)
data
# Out:
#    customerid          name
# 0           0      audi
# 1           1        bmx
# 2           2  toyota
# 3           3      ford

# %% [markdown]
# ## SELECT from a JSON file:

# %%
s = "SELECT id,name FROM `dfs.tmp`.`./names.json` limit 3"
data = pandas.read_sql(s, conn)
data
# Out:
#    id                            name
# 0   1  Erica Romaguera
# 1   2      Caleigh Jerde
# 2   3      Lucas Schultz

# %%
s = "SELECT id,address FROM `dfs.tmp`.`./addressunitedstates.json` limit 3"
data = pandas.read_sql(s, conn)
data
# Out:
#    id                                            address
# 0   1  728 Dooley Branch, Beck...
# 1   2  622 Dixie Path, South T...
# 2   3  20464 Lynch Haven, Emar...

# %% [markdown]
# ## JOIN fields across two JSON files:

# %%
# Here's how to do a JOIN
s = "SELECT tbl1.name, tbl2.address FROM `dfs.tmp`.`./names.json` as tbl1 JOIN `dfs.tmp`.`./addressunitedstates.json` as tbl2 ON tbl1.id=tbl2.id"
data = pandas.read_sql(s, conn)
data
# Out:
#                              na  \
# 0  Erica Romaguera
# 1      Caleigh Jerde
# 2      Lucas Schultz
#
#                                              addr
# 0  728 Dooley Branch, Beck...
# 1  622 Dixie Path, South T...
# 2  20464 Lynch Haven, Emar...

# %% [markdown]
# ## JOIN fields across a JSON file and a relational database:

# %%
# JOIN two fields
s = "SELECT tbl1.name, tbl2.name FROM `dfs.tmp`.`./names.json` as tbl1 JOIN ianmysql.cars.`car` as tbl2 ON tbl1.id=tbl2.customerid"
data = pandas.read_sql(s, conn)
data
# Out:
#                              name         name0
# 0  Erica Romaguera        bmx
# 1      Caleigh Jerde  toyota
# 2      Lucas Schultz      ford

# %%
# JOIN three fields
s = "SELECT tbl1.name, tbl2.address, tbl3.name as car FROM `dfs.tmp`.`./names.json` as tbl1 JOIN `dfs.tmp`.`./addressunitedstates.json` as tbl2 ON tbl1.id=tbl2.id JOIN ianmysql.cars.`car` as tbl3 ON tbl1.id=tbl3.customerid"
data = pandas.read_sql(s, conn)
data
# Out:
#                              name  \
# 0  Erica Romaguera
# 1      Caleigh Jerde
# 2      Lucas Schultz
#
#                                              address           car
# 0  728 Dooley Branch, Beck...        bmx
# 1  622 Dixie Path, South T...  toyota
# 2  20464 Lynch Haven, Emar...      ford

# %% [markdown]
# ## SELECT data from our Customer 360 CRM dataset in MapR-DB:

# %%
sql="SELECT * FROM `dfs.default`.`./tmp/crm_data`"
df=pd.read_sql(sql, conn)

# %%
df.head(5)
# Out:
#                                                  _id  \
# 0  000022e6-163d-4b2d-85e9...
# 1  00003d07-ee73-4fa8-9e3e...
# 2  0000cdd9-035e-493a-b1cf...
# 3  0000fad6-81d1-45bd-866d...
# 4  0002a290-21ee-4367-9be7...
#
#                                              address            birth_date  \
# 0       48578 Sandy Maple Edge  04/22/2001
# 1             64 Pretty Rock Dell  08/08/1974
# 2  32279 Grand Castle Stre...  07/15/1949
# 3   7103 Heather Axe Estates  12/21/1955
# 4  15388 Sunny Beaver Aven...  02/18/1945
#
#    churn_risk                                              email  \
# 0         6.0       CarlTaylor@example.com
# 1         2.0  RoslynSolomon@example.c...
# 2        20.0     SandraDavis@example.com
# 3         4.0         WayneHuls@example.com
# 4         5.0     IsiahIrving@example.com
#
#             first_visit        gender  \
# 0  07/15/2012  FEMALE
# 1  10/26/2003  FEMALE
# 2  12/05/2002      MALE
# 3  03/19/2010      MALE
# 4  10/14/2003      MALE
#
#                                                   id    latitude  \
# 0  000022e6-163d-4b2d-85e9...  31.95
# 1  00003d07-ee73-4fa8-9e3e...  38.45
# 2  0000cdd9-035e-493a-b1cf...  41.33
# 3  0000fad6-81d1-45bd-866d...  38.73
# 4  0002a290-21ee-4367-9be7...  39.57
#
#       longitude                                name  persona  \
# 0  -92.77            Eva Peterson      3.0
# 1  -82.64  Richard Escalante      2.0
# 2  -90.67                Joan Payne      1.0
# 3  -99.12        Rachel Worrell      3.0
# 4  -76.80          Nathan Porter      2.0
#
#                phone_number         sentiment                     ssn state  \
# 0  972-319-5949  POSITIVE  448-15-9240  wi
# 1  276-464-8090    NEUTRAL  530-78-7306  ga
# 2  809-358-1745  POSITIVE  034-99-8120  mi
# 3  788-666-9471  NEGATIVE  467-17-5304  ma
# 4  799-305-3641    NEUTRAL  530-65-8565  pa
#
#           zip
# 0  71410
# 1  41101
# 2  61279
# 3  67660
# 4  21155

# %% [markdown]
# ## Filter using a WHERE clause:

# %%
sql="SELECT * FROM `dfs.tmp`.`./crm_data` where ssn='448-15-9240'"
df=pd.read_sql(sql, conn)
df
# Out:
#                                                  _id  \
# 0  000022e6-163d-4b2d-85e9...
#
#                                         address            birth_date  \
# 0  48578 Sandy Maple Edge  04/22/2001
#
#    churn_risk                                         email  \
# 0         6.0  CarlTaylor@example.com
#
#             first_visit        gender  \
# 0  07/15/2012  FEMALE
#
#                                                   id    latitude  \
# 0  000022e6-163d-4b2d-85e9...  31.95
#
#       longitude                      name  persona              phone_number  \
# 0  -92.77  Eva Peterson      3.0  972-319-5949
#
#           sentiment                     ssn state         zip
# 0  POSITIVE  448-15-9240  wi  71410

# %%
sql="SELECT * FROM `dfs.tmp`.`./crm_data` where name='Erika Gallardo'"
df=pd.read_sql(sql, conn)
df
# Out:
#                                                  _id  \
# 0  0003c12c-ee2e-4ab8-a1dc...
#
#                                              address            birth_date  \
# 0  1545 Merry Bridge Orcha...  10/21/1981
#
#    churn_risk                                           email  \
# 0        29.0  KevinPalmer@example.com
#
#             first_visit        gender  \
# 0  01/25/2012  FEMALE
#
#                                                   id    latitude  \
# 0  0003c12c-ee2e-4ab8-a1dc...  44.94
#
#       longitude                          name  persona  \
# 0  -93.10  Erika Gallardo      3.0
#
#                phone_number         sentiment                     ssn state  \
# 0  817-938-5648  POSITIVE  529-42-0553  in
#
#           zip
# 0  55117

# %%
sql="SELECT * FROM `dfs.tmp`.`./crm_data` where name like '%bright%'"
df=pd.read_sql(sql, conn)
df.dropna().head(5)
# Out:
#                                                  _id  \
# 0  160b186a-ae6a-4163-98a8...
# 1  16573ac6-87f3-4fad-81de...
# 2  2174b3c1-6831-4525-ae6f...
# 3  22903282-a3b7-439e-8691...
# 4  2aa7a627-a6cd-4185-a014...
#
#                                             address            birth_date  \
# 0    5583 Golden Lake Canyon  12/31/1996
# 1        43280 Hidden Swan Cut  07/17/1994
# 2  3011 Cinder Prairie Glen  05/30/1936
# 3          6975 Tender Axe Pace  05/31/1981
# 4    64370 Happy Horse Niche  05/31/1937
#
#    churn_risk                                           email  \
# 0         4.0  VictorSmall@example.com
# 1        16.0    NellSeamon@example.com
# 2        16.0  MarthaWiley@example.com
# 3         6.0  JackieBurke@example.com
# 4        10.0  KathleenLam@example.com
#
#             first_visit        gender  \
# 0  08/26/1998      MALE
# 1  05/21/1995      MALE
# 2  01/24/2013  FEMALE
# 3  08/15/2003  FEMALE
# 4  09/09/2002  FEMALE
#
#                                                   id    latitude  \
# 0  160b186a-ae6a-4163-98a8...  40.31
# 1  16573ac6-87f3-4fad-81de...  35.10
# 2  2174b3c1-6831-4525-ae6f...  34.15
# 3  22903282-a3b7-439e-8691...  42.35
# 4  2aa7a627-a6cd-4185-a014...  35.82
#
#         longitude                                name  persona  \
# 0    -75.06      Johnny Albright      2.0
# 1    -90.00      Frank Hambright      3.0
# 2  -118.54        Ricky Albright      2.0
# 3    -71.06  Michelle Albright      2.0
# 4    -78.65    Justin Fulbright      2.0
#
#                phone_number         sentiment                     ssn state  \
# 0  663-654-6090    NEUTRAL  579-69-1115  in
# 1  193-393-5293  POSITIVE  267-71-8348  il
# 2  619-920-9455    NEUTRAL  317-44-2644  ny
# 3  457-651-5455  POSITIVE  500-28-5800  pa
# 4  554-265-6185    NEUTRAL  529-55-2084  wa
#
#           zip
# 0  18912
# 1  38188
# 2  91356
# 3  02297
# 4  27635

# %% [markdown]
# ## Instead of using a WHERE clause you can also filter using standard Python dataframe functions:

# %%
conn = pyodbc.connect("DSN=drill64", autocommit=True)
conn.setdecoding(pyodbc.SQL_CHAR, encoding='utf-32le', to=str)
conn.setdecoding(pyodbc.SQL_WMETADATA, encoding='utf-32le', to=str)
cursor = conn.cursor()
sql = "SELECT * FROM `dfs.tmp`.`./salary_data.csv2`"
df=pd.read_sql(sql, conn)
df[(df['name'].str.contains("ea"))]
# Out:
#                     name         salary years_experience  \
# 0          Keagan Klocko  92239.0868697                4
# 3           Shana Beahan  59978.9111169                3
# 16      Mireya Heathcote  48815.1639106                5
# 84   Deangelo Swaniawski  55705.7234414                3
# 103      Jeanne Schaefer  76916.9020765                7
# 163        Mayra Gleason  72661.5777432                4
# 232      Breana Gottlieb  41255.6678519                0
#
#                        fqn          filename filepath suffix
# 0    /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 3    /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 16   /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 84   /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 103  /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 163  /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
# 232  /tmp/salary_data.csv2  salary_data.csv2     /tmp   csv2
